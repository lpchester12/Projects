# %% [markdown]
# ## Description
#
# * Data cleaning is mainly done in this notebook.

# %% [markdown]
# ## Variable Description

# %% [markdown]
# * **Medicine Name**: The name of the medicine.
#
# * **Composition**: The chemical composition or ingredients of the medicine.
#
# * **Uses**: The medical uses or indications for which the medicine is prescribed.
#
# * **Side\_effects**: Potential side effects associated with the medicine.
#
# * **Image URL**: URL link to an image of the medicine.
#
# * **Manufacturer**: The company that manufactures the medicine.
#
# * **Excellent Review %**: Percentage of excellent reviews for the medicine.
#
# * **Average Review %**: Percentage of average reviews for the medicine.
#
# * **Poor Review %**: Percentage of poor reviews for the medicine.
#
# Data Source: https://www.kaggle.com/datasets/singhnavjot2062001/11000-medicine-details

# %%
# Import Necessary Libararies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read and copy the data
data = pd.read_csv('YOUR_PATH')
df = data.copy()

# %%
# Check data shape
df.shape
# Out:
# (11825, 9)

# %% [markdown]
# * The dataset has 11825 rows and 9 columns

# %%
# Check 5 samples from the data
df.head()
# Out:
#               Medicine Name  \
# 0   Avastin 400mg Injection
# 1  Augmentin 625 Duo Tablet
# 2       Azithral 500 Tablet
# 3          Ascoril LS Syrup
# 4         Aciloc 150 Tablet
#
#                                          Composition  \
# 0                                Bevacizumab (400mg)
# 1    Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 2                               Azithromycin (500mg)
# 3  Ambroxol (30mg/5ml) + Levosalbutamol (1mg/5ml)...
# 4                                 Ranitidine (150mg)
#
#                                                 Uses  \
# 0   Cancer of colon and rectum Non-small cell lun...
# 1                  Treatment of Bacterial infections
# 2                  Treatment of Bacterial infections
# 3                      Treatment of Cough with mucus
# 4  Treatment of Gastroesophageal reflux disease (...
#
#                                         Side_effects  \
# 0  Rectal bleeding Taste change Headache Noseblee...
# 1  Vomiting Nausea Diarrhea Mucocutaneous candidi...
# 2                     Nausea Abdominal pain Diarrhea
# 3  Nausea Vomiting Diarrhea Upset stomach Stomach...
# 4     Headache Diarrhea Gastrointestinal disturbance
#
#                                            Image URL  \
# 0  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 1  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 2  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 3  https://onemg.gumlet.io/l_watermark_346,w_480,...
# 4  https://onemg.gumlet.io/l_watermark_346,w_480,...
#
#                            Manufacturer  Excellent Review %  Average Review %  \
# 0          Roche Products India Pvt Ltd                  22                56
# 1  Glaxo SmithKline Pharmaceuticals Ltd                  47                35
# 2           Alembic Pharmaceuticals Ltd                  39                40
# 3          Glenmark Pharmaceuticals Ltd                  24                41
# 4            Cadila Pharmaceuticals Ltd                  34                37
#
#    Poor Review %
# 0             22
# 1             18
# 2             21
# 3             35
# 4             29

# %%
# Check basic data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11825 entries, 0 to 11824
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Medicine Name       11825 non-null  object
#  1   Composition         11825 non-null  object
#  2   Uses                11825 non-null  object
#  3   Side_effects        11825 non-null  object
#  4   Image URL           11825 non-null  object
#  5   Manufacturer        11825 non-null  object
#  6   Excellent Review %  11825 non-null  int64
#  7   Average Review %    11825 non-null  int64
#  8   Poor Review %       11825 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 831.6+ KB

# %% [markdown]
# * The data does not seem to have null values.
# * It is consisted of 6 features with object data type and 3 features with integer data type.

# %%
# Check duplication
df.duplicated().sum()
# Out:
# np.int64(84)

# %% [markdown]
# * There are 84 overlapping samples.

# %%
# Drop the duplicated rows
df.drop_duplicates(inplace = True)
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# * Duplicated rows are successfully dropped.

# %%
# Check for null values to be sure
df.isnull().sum()
# Out:
# Medicine Name         0
# Composition           0
# Uses                  0
# Side_effects          0
# Image URL             0
# Manufacturer          0
# Excellent Review %    0
# Average Review %      0
# Poor Review %         0
# dtype: int64

# %% [markdown]
# * There are no null values in the data as observed in the information.

# %%
# Check the values in categorical features
cat_cols = df.select_dtypes(include = 'object').columns.tolist()
for col in df[cat_cols]:
  print(df[col].value_counts(1))
  print('-' * 50)
# Out:
# Medicine Name
# Lulifin Cream                        0.000341
# Hexidine Mouth Wash                  0.000256
# Amrolstar Cream                      0.000256
# Lulizol Cream                        0.000256
# Numbex Cream                         0.000256
#                                        ...
# Jilazo Solution for Injection        0.000085
# Justin 12.5mg Suppository            0.000085
# Just Tears Liquigel                  0.000085
# Jenvac Vaccine                       0.000085
# Jardiance Met 12.5mg/500mg Tablet    0.000085
# Name: proportion, Length: 11498, dtype: float64
# --------------------------------------------------
# Composition
# Luliconazole (1% w/w)                           0.008347
# Levocetirizine (5mg) + Montelukast (10mg)       0.006473
# Ketoconazole (2% w/w)                           0.005195
# Domperidone (30mg) + Rabeprazole (20mg)         0.005025
# Itraconazole (100mg)                            0.004514
#                                                   ...
# Cefixime (25mg/ml)                              0.000085
# Fluconazole (150mg) + Tinidazole (1000mg)       0.000085
# Cefuroxime (250mg) + Clavulanic Acid (125mg)    0.000085
# Fluconazole (100mg)                             0.000085
# Octenidine (0.05% w/v)                          0.000085
# Name: proportion, Length: 3358, dtype: float64
# --------------------------------------------------
# Uses
# Treatment of Type 2 diabetes mellitus                                           0.076995
# Treatment of Bacterial infections                                               0.036964
#  Hypertension (high blood pressure)                                             0.034324
#  Pain relief                                                                    0.032450
# Treatment of Hypertension (high blood pressure)                                 0.023593
#                                                                                   ...
#  Breast cancer Cancer of colon and rectum                                       0.000085
# Treatment of Bacterial eye / ear infectionsTreatment of Bacterial infections    0.000085
# Treatment of Fungal infections of vagina                                        0.000085
#  Fungal infections of eyeTreatment of Fungal infections                         0.000085
#  Blood cancer (Acute lymphocytic leukemia)                                      0.000085
# Name: proportion, Length: 712, dtype: float64
# --------------------------------------------------
# Side_effects
# Application site reactions burning irritation itching and redness                                                         0.033132
# Hypoglycemia low blood glucose level Headache Nausea Diarrhea Flatulence                                                  0.014735
# No common side effects seen                                                                                               0.012520
# Dizziness Sleepiness Tiredness Uncoordinated body movements                                                               0.010476
# Application site reactions burning irritation itching and redness Dry skin Skin peeling Blisters on skin                  0.010050
#                                                                                                                             ...
# Dizziness Dryness in mouth Nausea Taste change Drowsiness Peripheral neuropathy tingling and numbness of feet and hand    0.000085
# Eye irritation Stinging in the eyes Headache Nausea Stomach pain                                                          0.000085
# Diarrhea Nausea Vomiting Stomach pain Dryness in mouth Metallic taste Headache Rash                                       0.000085
# Nausea Vomiting Diarrhea Stomach pain Indigestion Flatulence                                                              0.000085
# Nausea Vomiting Diarrhea Dizziness Headache Body ache Skin rash                                                           0.000085
# Name: proportion, Length: 1512, dtype: float64
# --------------------------------------------------
# Image URL
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/d7ea42a45bf443399f4ef4de69efc3a7.jpg    0.000170
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/cropped/y9lxx14dom5ljmqi36kg.jpg        0.000085
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/cropped/uzgn0aik0qkvktqt9xfj.jpg        0.000085
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/hi6vkvh4g9kajev9vy26.jpg                0.000085
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/cropped/elb6vve1bgp8rie2xkwq.jpg        0.000085
#                                                                                                                                        ...
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/cropped/ogc15cnejd4uh2qwxgau.jpg        0.000085
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/cropped/ehrbsu1zw1rqun8ygmgh.jpg        0.000085
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/cropped/snpqurldn6a6ujhegjrf.jpg        0.000085
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/cropped/jlcjyzc5fzu32oyvucqp.jpg        0.000085
# https://onemg.gumlet.io/l_watermark_346,w_480,h_480/a_ignore,w_480,h_480,c_fit,q_auto,f_auto/1b0551b995e8465eb21c29ebb2561f4b.jpg    0.000085
# Name: proportion, Length: 11740, dtype: float64
# --------------------------------------------------
# Manufacturer
# Sun Pharmaceutical Industries Ltd         0.069756
# Intas Pharmaceuticals Ltd                 0.055191
# Cipla Ltd                                 0.048463
# Torrent Pharmaceuticals Ltd               0.037561
# Lupin Ltd                                 0.036794
#                                             ...
# Biomiicron Pharmaceuticals                0.000085
# Vkan healthcare                           0.000085
# Krishna Life Sciences                     0.000085
# Santis Pharmaceuticals Private Limited    0.000085
# Bionucleus Pharmaceuticals Pvt Ltd        0.000085
# Name: proportion, Length: 759, dtype: float64
# --------------------------------------------------

# %% [markdown]
# * The categorical features does not seem to have obscure values to be eliminated.

# %%
# Save the cleaned data to the google drive
df.to_csv('YOUR_PATH', index=False)
