# %%
# %%capture --no-stderr
# %pip install numpy==1.26.4 langchain-community langchain-chroma langchain-huggingface nbimporter

# %% [markdown]
# ## Description
#
# * This notebook will create a vector database that will be used to store the data.
# * The vector database and the embedding model will be stored in google drive for later use.

# %%
# Import the necessary libraries for the tasks
import numpy as np
import transformers
import torch
import os
import nbimporter
from langchain_huggingface import HuggingFaceEmbeddings
from sentence_transformers import SentenceTransformer
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Use API KEYS saved in constant notebook
import nbimporter

# %run 'YOUR_PATH'

os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY
os.environ['LANGSMITH_API_KEY'] = LANGSMITH_API_KEY
os.environ["LANGSMITH_TRACING"] = "true"
os.environ['HF_TOKEN'] = HF_TOKEN
os.environ['USER_AGENT'] = 'Mozilla/5.0'

print(OPENAI_API_KEY[:5])
print(LANGSMITH_API_KEY[:5])
# Out:
# sk-pr
# lsv2_

# %%
# Set up embedding model for vector database

embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    encode_kwargs={"batch_size": 64}
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
# Create and save the embedding model
embedding_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
embedding_model.save("/content/drive/MyDrive/Project/Project/DEMO_APP_Medicine_info/embedding_model")
